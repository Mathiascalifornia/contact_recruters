# %%
import time

import pandas as pd 

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

from config import *

# %%
def send_email_with_attachment(sender_email, sender_password, recipient_email, subject, message_body, attachment_path):
    # SMTP server configuration (Gmail in this example)
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587  # TLS port

    # Create the message
    msg = MIMEMultipart()
    msg['From'] = sender_email
    msg['To'] = recipient_email
    msg['Subject'] = subject

    # Add message body
    msg.attach(MIMEText(message_body, 'plain'))

    # Add attachment
    attachment = open(attachment_path, "rb")
    part = MIMEBase('application', 'octet-stream')
    part.set_payload(attachment.read())
    encoders.encode_base64(part)
    part.add_header('Content-Disposition', f"attachment; filename= {attachment_path}")
    msg.attach(part)

    # Connect to SMTP server and send email
    try:
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()  # Enable TLS encryption
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, recipient_email, msg.as_string())
        server.quit()
        print("Email sent successfully!")
    except Exception as e:
        print("Error sending email:", str(e))

# %%
for i in df.index:
    subset = df.loc[i]

    prenom = subset["Prénom"].strip()
    recevier_email = subset["Mail Pylote"].strip()

    mail = template_mail.format(prenom)

    send_email_with_attachment(sender_email=my_email,
                               sender_password=my_password_email,
                               recipient_email=recevier_email,
                               subject=subject,
                               attachment_path=path_attachment,
                               message_body=mail)
    
    time.sleep(1)
# Out:
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# Email sent successfully!
# ...
